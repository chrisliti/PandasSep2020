# %%
import pandas as pd
import os

# %%
os.chdir("/home/chris/Tutorials/Pandas Materials/2.1 Course_Materials_Part2/Course_Materials_Part2/Video_Lecture_NBs")

# %% [markdown]
# ## Concatenating Rows

# %%
men2004 = pd.read_csv("men2004.csv")

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2004.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 2 columns):
# Athlete    59 non-null object
# Medals     59 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 1.0+ KB

# %%
men2008 = pd.read_csv("men2008.csv")

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men2008.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 2 columns):
# Athlete    62 non-null object
# Medals     62 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB

# %%
men2004.append(men2008,ignore_index=True)
# Out:
#               Athlete  Medals
# 0     PHELPS, Michael       8
# 1         THORPE, Ian       4
# 2    SCHOEMAN, Roland       3
# 3      PEIRSOL, Aaron       3
# 4        CROCKER, Ian       3
# ..                ...     ...
# 116  LAGUNOV, Evgeniy       1
# 117     BERENS, Ricky       1
# 118      LURZ, Thomas       1
# 119   MALLET, Gregory       1
# 120        ZHANG, Lin       1
#
# [121 rows x 2 columns]

# %%
men0408 = pd.concat([men2004,men2008],ignore_index=False,keys=[2004,2008],names= ["Year"])

# %%
men0408.reset_index().drop(columns="level_1")
# Out:
#      Year           Athlete  Medals
# 0    2004   PHELPS, Michael       8
# 1    2004       THORPE, Ian       4
# 2    2004  SCHOEMAN, Roland       3
# 3    2004    PEIRSOL, Aaron       3
# 4    2004      CROCKER, Ian       3
# ..    ...               ...     ...
# 116  2008  LAGUNOV, Evgeniy       1
# 117  2008     BERENS, Ricky       1
# 118  2008      LURZ, Thomas       1
# 119  2008   MALLET, Gregory       1
# 120  2008        ZHANG, Lin       1
#
# [121 rows x 3 columns]

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men2004.columns = ["Name","Medals"]

# %%
men2004["Success"] = "Yes"

# %%
men2004.head()
# Out:
#                Name  Medals Success
# 0   PHELPS, Michael       8     Yes
# 1       THORPE, Ian       4     Yes
# 2  SCHOEMAN, Roland       3     Yes
# 3    PEIRSOL, Aaron       3     Yes
# 4      CROCKER, Ian       3     Yes

# %%
pd.concat([men2004,men2008],keys=[2004,2008],names=["Year"])
# Out:
# /home/chris/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                   Athlete  Medals              Name Success
# Year
# 2004 0                NaN       8   PHELPS, Michael     Yes
#      1                NaN       4       THORPE, Ian     Yes
#      2                NaN       3  SCHOEMAN, Roland     Yes
#      3                NaN       3    PEIRSOL, Aaron     Yes
#      4                NaN       3      CROCKER, Ian     Yes
# ...                   ...     ...               ...     ...
# 2008 57  LAGUNOV, Evgeniy       1               NaN     NaN
#      58     BERENS, Ricky       1               NaN     NaN
#      59      LURZ, Thomas       1               NaN     NaN
#      60   MALLET, Gregory       1               NaN     NaN
#      61        ZHANG, Lin       1               NaN     NaN
#
# [121 rows x 4 columns]

# %%
men2004.drop(labels=["Success"],axis=1,inplace=True)

# %%
men2004.head()
# Out:
#                Name  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.columns = men2004.columns

# %%
men2008.head()
# Out:
#                   Name  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men2004 = pd.read_csv("men2004.csv",index_col="Athlete")
men2008 = pd.read_csv("men2008.csv",index_col="Athlete")

# %%
men2004.head()
# Out:
#                   Medals
# Athlete
# PHELPS, Michael        8
# THORPE, Ian            4
# SCHOEMAN, Roland       3
# PEIRSOL, Aaron         3
# CROCKER, Ian           3

# %%
men2008.head()
# Out:
#                      Medals
# Athlete
# PHELPS, Michael           8
# LOCHTE, Ryan              4
# BERNARD, Alain            3
# SULLIVAN, Eamon           3
# LAUTERSTEIN, Andrew       3

# %%
pd.concat([men2004,men2008],keys=[2004,2008],ignore_index=False)
# Out:
#                        Medals
#      Athlete
# 2004 PHELPS, Michael        8
#      THORPE, Ian            4
#      SCHOEMAN, Roland       3
#      PEIRSOL, Aaron         3
#      CROCKER, Ian           3
# ...                       ...
# 2008 LAGUNOV, Evgeniy       1
#      BERENS, Ricky          1
#      LURZ, Thomas           1
#      MALLET, Gregory        1
#      ZHANG, Lin             1
#
# [121 rows x 1 columns]

# %%
pd.concat([men2004,men2008],keys=[2004,2008],ignore_index=True)
# Out:
#      Medals
# 0         8
# 1         4
# 2         3
# 3         3
# 4         3
# ..      ...
# 116       1
# 117       1
# 118       1
# 119       1
# 120       1
#
# [121 rows x 1 columns]

# %%
topfive_2004 = pd.read_csv("topfive_2004.csv",index_col="Athlete")
topfive_2008 = pd.read_csv("topfive_2008.csv",index_col="Athlete")

# %%
topfive_2004.head()
# Out:
#                   Gold  Silver  Bronze
# Athlete
# PHELPS, Michael    6.0     0.0     2.0
# PEIRSOL, Aaron     3.0     0.0     0.0
# THORPE, Ian        2.0     1.0     1.0
# KITAJIMA, Kosuke   2.0     0.0     1.0
# HACKETT, Grant     1.0     2.0     0.0

# %%
topfive_2008.head()
# Out:
#                   Gold  Silver  bronze
# Athlete
# PHELPS, Michael    8.0     0.0     0.0
# GREVERS, Matt      2.0     1.0     0.0
# PEIRSOL, Aaron     2.0     1.0     0.0
# LOCHTE, Ryan       2.0     0.0     2.0
# KITAJIMA, Kosuke   2.0     0.0     1.0

# %%
topfive_2004 + topfive_2008
# Out:
#                   Bronze  Gold  Silver  bronze
# Athlete
# GREVERS, Matt        NaN   NaN     NaN     NaN
# HACKETT, Grant       NaN   NaN     NaN     NaN
# KITAJIMA, Kosuke     NaN   4.0     0.0     NaN
# LOCHTE, Ryan         NaN   NaN     NaN     NaN
# PEIRSOL, Aaron       NaN   5.0     1.0     NaN
# PHELPS, Michael      NaN  14.0     0.0     NaN
# THORPE, Ian          NaN   NaN     NaN     NaN

# %%
topfive_2004.add(topfive_2008,fill_value=0)
# Out:
#                   Bronze  Gold  Silver  bronze
# Athlete
# GREVERS, Matt        NaN   2.0     1.0     0.0
# HACKETT, Grant       0.0   1.0     2.0     NaN
# KITAJIMA, Kosuke     1.0   4.0     0.0     1.0
# LOCHTE, Ryan         NaN   2.0     0.0     2.0
# PEIRSOL, Aaron       0.0   5.0     1.0     0.0
# PHELPS, Michael      2.0  14.0     0.0     0.0
# THORPE, Ian          1.0   2.0     1.0     NaN

# %%
topfive_2008.rename(columns={"bronze":"Bronze"},inplace=True)

# %%
topfive_2004.add(topfive_2008,fill_value=0)
# Out:
#                   Gold  Silver  Bronze
# Athlete
# GREVERS, Matt      2.0     1.0     0.0
# HACKETT, Grant     1.0     2.0     0.0
# KITAJIMA, Kosuke   4.0     0.0     2.0
# LOCHTE, Ryan       2.0     0.0     2.0
# PEIRSOL, Aaron     5.0     1.0     0.0
# PHELPS, Michael   14.0     0.0     2.0
# THORPE, Ian        2.0     1.0     1.0

# %%
topfive_2004.sub(topfive_2008,fill_value=0)
# Out:
#                   Gold  Silver  Bronze
# Athlete
# GREVERS, Matt     -2.0    -1.0     0.0
# HACKETT, Grant     1.0     2.0     0.0
# KITAJIMA, Kosuke   0.0     0.0     0.0
# LOCHTE, Ryan      -2.0     0.0    -2.0
# PEIRSOL, Aaron     1.0    -1.0     0.0
# PHELPS, Michael   -2.0     0.0     2.0
# THORPE, Ian        2.0     1.0     1.0

# %%
topfive_2004.mul(topfive_2008,fill_value=0)
# Out:
#                   Gold  Silver  Bronze
# Athlete
# GREVERS, Matt      0.0     0.0     0.0
# HACKETT, Grant     0.0     0.0     0.0
# KITAJIMA, Kosuke   4.0     0.0     1.0
# LOCHTE, Ryan       0.0     0.0     0.0
# PEIRSOL, Aaron     6.0     0.0     0.0
# PHELPS, Michael   48.0     0.0     0.0
# THORPE, Ian        0.0     0.0     0.0

# %%
topfive_2004.div(topfive_2008,fill_value=0)
# Out:
#                   Gold  Silver  Bronze
# Athlete
# GREVERS, Matt     0.00     0.0     NaN
# HACKETT, Grant     inf     inf     NaN
# KITAJIMA, Kosuke  1.00     NaN     1.0
# LOCHTE, Ryan      0.00     NaN     0.0
# PEIRSOL, Aaron    1.50     0.0     NaN
# PHELPS, Michael   0.75     NaN     inf
# THORPE, Ian        inf     inf     inf

# %% [markdown]
# ## Outer Joins

# %%
men2004 = pd.read_csv("men2004.csv")
men2008 = pd.read_csv("men2008.csv")

# %%
men2004.shape
# Out:
# (59, 2)

# %%
men2008.shape
# Out:
# (62, 2)

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2004.merge(men2008,how="outer",on="Athlete",suffixes=("_2004","_2008"),indicator=True)
# Out:
#               Athlete  Medals_2004  Medals_2008      _merge
# 0     PHELPS, Michael          8.0          8.0        both
# 1         THORPE, Ian          4.0          NaN   left_only
# 2    SCHOEMAN, Roland          3.0          NaN   left_only
# 3      PEIRSOL, Aaron          3.0          3.0        both
# 4        CROCKER, Ian          3.0          1.0        both
# ..                ...          ...          ...         ...
# 100  LAGUNOV, Evgeniy          NaN          1.0  right_only
# 101     BERENS, Ricky          NaN          1.0  right_only
# 102      LURZ, Thomas          NaN          1.0  right_only
# 103   MALLET, Gregory          NaN          1.0  right_only
# 104        ZHANG, Lin          NaN          1.0  right_only
#
# [105 rows x 4 columns]

# %%
men0408 = men2004.merge(men2008,how="outer",on="Athlete",suffixes=("_2004","_2008"),indicator=True)
men0408
# Out:
#               Athlete  Medals_2004  Medals_2008      _merge
# 0     PHELPS, Michael          8.0          8.0        both
# 1         THORPE, Ian          4.0          NaN   left_only
# 2    SCHOEMAN, Roland          3.0          NaN   left_only
# 3      PEIRSOL, Aaron          3.0          3.0        both
# 4        CROCKER, Ian          3.0          1.0        both
# ..                ...          ...          ...         ...
# 100  LAGUNOV, Evgeniy          NaN          1.0  right_only
# 101     BERENS, Ricky          NaN          1.0  right_only
# 102      LURZ, Thomas          NaN          1.0  right_only
# 103   MALLET, Gregory          NaN          1.0  right_only
# 104        ZHANG, Lin          NaN          1.0  right_only
#
# [105 rows x 4 columns]

# %%
men0408._merge.value_counts()
# Out:
# right_only    46
# left_only     43
# both          16
# Name: _merge, dtype: int64

# %% [markdown]
# ## Inner Joins

# %%
men2004.merge(men2008,how="inner",on="Athlete",suffixes=("_2004","_2008"),indicator=True)
# Out:
#               Athlete  Medals_2004  Medals_2008 _merge
# 0     PHELPS, Michael            8            8   both
# 1      PEIRSOL, Aaron            3            3   both
# 2        CROCKER, Ian            3            1   both
# 3    KITAJIMA, Kosuke            3            3   both
# 4     HANSEN, Brendan            3            1   both
# 5      HACKETT, Grant            3            2   both
# 6        LEZAK, Jason            2            3   both
# 7       KELLER, Klete            2            1   both
# 8        LOCHTE, Ryan            2            4   both
# 9         VENDT, Erik            1            1   both
# 10  VANDERKAAY, Peter            1            2   both
# 11       CSEH, Laszlo            1            3   both
# 12      DAVIES, David            1            1   both
# 13    DUBOSCQ, Hugues            1            2   both
# 14     GANGLOFF, Mark            1            1   both
# 15     JENSEN, Larsen            1            1   both

# %% [markdown]
# ## Outer Join Without Intersection (Opposite of Inner Join)

# %%
men0408 = men2004.merge(men2008,how="outer",on="Athlete",suffixes=("_2004","_2008"),indicator=True)
men0408.head()
# Out:
#             Athlete  Medals_2004  Medals_2008     _merge
# 0   PHELPS, Michael          8.0          8.0       both
# 1       THORPE, Ian          4.0          NaN  left_only
# 2  SCHOEMAN, Roland          3.0          NaN  left_only
# 3    PEIRSOL, Aaron          3.0          3.0       both
# 4      CROCKER, Ian          3.0          1.0       both

# %%
men0408.loc[men0408._merge != "both"]
# Out:
#                         Athlete  Medals_2004  Medals_2008      _merge
# 1                   THORPE, Ian          4.0          NaN   left_only
# 2              SCHOEMAN, Roland          3.0          NaN   left_only
# 7    VAN DEN HOOGENBAND, Pieter          3.0          NaN   left_only
# 9                MORITA, Tomomi          2.0          NaN   left_only
# 11                ROGAN, Markus          2.0          NaN   left_only
# ..                          ...          ...          ...         ...
# 100            LAGUNOV, Evgeniy          NaN          1.0  right_only
# 101               BERENS, Ricky          NaN          1.0  right_only
# 102                LURZ, Thomas          NaN          1.0  right_only
# 103             MALLET, Gregory          NaN          1.0  right_only
# 104                  ZHANG, Lin          NaN          1.0  right_only
#
# [89 rows x 4 columns]

# %% [markdown]
# ## Left Join Without Intersection

# %%
men0408 = men2004.merge(men2008,how="outer",on="Athlete",suffixes=("_2004","_2008"),indicator=True)
men0408.head()
# Out:
#             Athlete  Medals_2004  Medals_2008     _merge
# 0   PHELPS, Michael          8.0          8.0       both
# 1       THORPE, Ian          4.0          NaN  left_only
# 2  SCHOEMAN, Roland          3.0          NaN  left_only
# 3    PEIRSOL, Aaron          3.0          3.0       both
# 4      CROCKER, Ian          3.0          1.0       both

# %%
men0408.loc[men0408._merge == "left_only"].shape
# Out:
# (43, 4)

# %% [markdown]
# ## Right Join Without Intersection

# %%
men0408 = men2004.merge(men2008,how="outer",on="Athlete",suffixes=("_2004","_2008"),indicator=True)
men0408.head()
# Out:
#             Athlete  Medals_2004  Medals_2008     _merge
# 0   PHELPS, Michael          8.0          8.0       both
# 1       THORPE, Ian          4.0          NaN  left_only
# 2  SCHOEMAN, Roland          3.0          NaN  left_only
# 3    PEIRSOL, Aaron          3.0          3.0       both
# 4      CROCKER, Ian          3.0          1.0       both

# %%
men0408.loc[men0408._merge == "right_only"].shape
# Out:
# (46, 4)

# %% [markdown]
# ## Left Join

# %%
men2004.shape
# Out:
# (59, 2)

# %%
men0408 = men2004.merge(men2008,how="left",on="Athlete",suffixes=("_2004","_2008"),indicator=True)

# %%
men0408.shape
# Out:
# (59, 4)

# %%
men0408.head()
# Out:
#             Athlete  Medals_2004  Medals_2008     _merge
# 0   PHELPS, Michael            8          8.0       both
# 1       THORPE, Ian            4          NaN  left_only
# 2  SCHOEMAN, Roland            3          NaN  left_only
# 3    PEIRSOL, Aaron            3          3.0       both
# 4      CROCKER, Ian            3          1.0       both

# %% [markdown]
# ## Right Join

# %%
men2008.shape
# Out:
# (62, 2)

# %%
men0408 = men2004.merge(men2008,how="right",on="Athlete",suffixes=("_2004","_2008"),indicator=True)

# %%
men0408.shape
# Out:
# (62, 4)

# %%
men0408.tail()
# Out:
#              Athlete  Medals_2004  Medals_2008      _merge
# 57  LAGUNOV, Evgeniy          NaN            1  right_only
# 58     BERENS, Ricky          NaN            1  right_only
# 59      LURZ, Thomas          NaN            1  right_only
# 60   MALLET, Gregory          NaN            1  right_only
# 61        ZHANG, Lin          NaN            1  right_only

# %% [markdown]
# ## Joining On different column labels

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men2004.columns = ["Name","Medals"]

# %%
men0408 = men2004.merge(men2008,how="outer",left_on="Name",right_on="Athlete",suffixes=("_2004","_2008"),indicator=True)

# %%
men0408.head()
# Out:
#                Name  Medals_2004          Athlete  Medals_2008     _merge
# 0   PHELPS, Michael          8.0  PHELPS, Michael          8.0       both
# 1       THORPE, Ian          4.0              NaN          NaN  left_only
# 2  SCHOEMAN, Roland          3.0              NaN          NaN  left_only
# 3    PEIRSOL, Aaron          3.0   PEIRSOL, Aaron          3.0       both
# 4      CROCKER, Ian          3.0     CROCKER, Ian          1.0       both

# %%
men0408.Name.fillna(men0408.Athlete,inplace=True)

# %%
men0408.head()
# Out:
#                Name  Medals_2004          Athlete  Medals_2008     _merge
# 0   PHELPS, Michael          8.0  PHELPS, Michael          8.0       both
# 1       THORPE, Ian          4.0              NaN          NaN  left_only
# 2  SCHOEMAN, Roland          3.0              NaN          NaN  left_only
# 3    PEIRSOL, Aaron          3.0   PEIRSOL, Aaron          3.0       both
# 4      CROCKER, Ian          3.0     CROCKER, Ian          1.0       both

# %%
men0408.drop(["Athlete","_merge"],axis=1,inplace=True)

# %%
men2008.set_index("Athlete",inplace=True)

# %%
men2008.head()
# Out:
#                      Medals
# Athlete
# PHELPS, Michael           8
# LOCHTE, Ryan              4
# BERNARD, Alain            3
# SULLIVAN, Eamon           3
# LAUTERSTEIN, Andrew       3

# %%
men2004.merge(men2008,how="outer",left_on="Name",right_index=True,suffixes=("_2004","_2008"),indicator=True)
# Out:
#                  Name  Medals_2004  Medals_2008      _merge
# 0.0   PHELPS, Michael          8.0          8.0        both
# 1.0       THORPE, Ian          4.0          NaN   left_only
# 2.0  SCHOEMAN, Roland          3.0          NaN   left_only
# 3.0    PEIRSOL, Aaron          3.0          3.0        both
# 4.0      CROCKER, Ian          3.0          1.0        both
# ..                ...          ...          ...         ...
# NaN  LAGUNOV, Evgeniy          NaN          1.0  right_only
# NaN     BERENS, Ricky          NaN          1.0  right_only
# NaN      LURZ, Thomas          NaN          1.0  right_only
# NaN   MALLET, Gregory          NaN          1.0  right_only
# NaN        ZHANG, Lin          NaN          1.0  right_only
#
# [105 rows x 4 columns]

# %% [markdown]
# ## Joining on many columns

# %%
men2004_det = pd.read_csv("men2004_det.csv")
men2008_det = pd.read_csv("men2008_det.csv")

# %%
men2004_det.head()
# Out:
#                  Athlete   Medal  Count
# 0         BOVELL, George  Bronze      1
# 1    BREMBILLA, Emiliano  Bronze      1
# 2  CAPPELLAZZO, Federico  Bronze      1
# 3        CERCATO, Simone  Bronze      1
# 4           CONRAD, Lars  Silver      1

# %%
men2008_det.head()
# Out:
#           Athlete   Medal  Count
# 0  ADRIAN, Nathan    Gold      1
# 1   BERENS, Ricky    Gold      1
# 2  BERNARD, Alain  Bronze      1
# 3  BERNARD, Alain    Gold      1
# 4  BERNARD, Alain  Silver      1

# %%
men2004_det.loc[men2004_det.Athlete == "PHELPS, Michael"]
# Out:
#             Athlete   Medal  Count
# 50  PHELPS, Michael  Bronze      2
# 51  PHELPS, Michael    Gold      6

# %%
men2008_det.loc[men2008_det.Athlete == "PHELPS, Michael"]
# Out:
#             Athlete Medal  Count
# 54  PHELPS, Michael  Gold      8

# %%
men0408 = men2004_det.merge(men2008_det,how="outer",on="Athlete",suffixes=("_2004","_2008"),indicator=True)

# %%
men0408
# Out:
#                    Athlete Medal_2004  Count_2004 Medal_2008  Count_2008  \
# 0           BOVELL, George     Bronze         1.0        NaN         NaN
# 1      BREMBILLA, Emiliano     Bronze         1.0        NaN         NaN
# 2    CAPPELLAZZO, Federico     Bronze         1.0        NaN         NaN
# 3          CERCATO, Simone     Bronze         1.0        NaN         NaN
# 4             CONRAD, Lars     Silver         1.0        NaN         NaN
# ..                     ...        ...         ...        ...         ...
# 137     VYATCHANIN, Arkady        NaN         NaN     Bronze         2.0
# 138         WALTERS, David        NaN         NaN       Gold         1.0
# 139    WEBER-GALE, Garrett        NaN         NaN       Gold         2.0
# 140  WILDMAN-TOBRINER, Ben        NaN         NaN       Gold         1.0
# 141             ZHANG, Lin        NaN         NaN     Silver         1.0
#
#          _merge
# 0     left_only
# 1     left_only
# 2     left_only
# 3     left_only
# 4     left_only
# ..          ...
# 137  right_only
# 138  right_only
# 139  right_only
# 140  right_only
# 141  right_only
#
# [142 rows x 6 columns]

# %%
men0408.loc[men0408.Athlete == "PHELPS, Michael"]
# Out:
#             Athlete Medal_2004  Count_2004 Medal_2008  Count_2008 _merge
# 59  PHELPS, Michael     Bronze         2.0       Gold         8.0   both
# 60  PHELPS, Michael       Gold         6.0       Gold         8.0   both

# %%
men0408 = men2004_det.merge(men2008_det,how="outer",on=["Athlete","Medal"],suffixes=("_2004","_2008"),indicator=True)

# %%
men0408.loc[men0408.Athlete == "PHELPS, Michael"]
# Out:
#             Athlete   Medal  Count_2004  Count_2008     _merge
# 50  PHELPS, Michael  Bronze         2.0         NaN  left_only
# 51  PHELPS, Michael    Gold         6.0         8.0       both

# %%
men0408 = men2004_det.merge(men2008_det,how="inner",on=["Athlete","Medal"],suffixes=("_2004","_2008"),indicator=True)

# %%
men0408.loc[men0408.Athlete == "PHELPS, Michael"]
# Out:
#             Athlete Medal  Count_2004  Count_2008 _merge
# 12  PHELPS, Michael  Gold           6           8   both

# %%
men2004.join(men2008,how="outer",lsuffix="_2004",rsuffix="_2008")
# Out:
#                                    Name  Medals_2004  Medals_2008
# 0                       PHELPS, Michael          8.0          NaN
# 1                           THORPE, Ian          4.0          NaN
# 2                      SCHOEMAN, Roland          3.0          NaN
# 3                        PEIRSOL, Aaron          3.0          NaN
# 4                          CROCKER, Ian          3.0          NaN
# ...                                 ...          ...          ...
# VYATCHANIN, Arkady                  NaN          NaN          2.0
# WALTERS, David                      NaN          NaN          1.0
# WEBER-GALE, Garrett                 NaN          NaN          2.0
# WILDMAN-TOBRINER, Ben               NaN          NaN          1.0
# ZHANG, Lin                          NaN          NaN          1.0
#
# [121 rows x 3 columns]
