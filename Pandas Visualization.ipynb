# %%
import os
import pandas as pd

# %%
os.chdir("/home/chris/Tutorials/Pandas Materials/2.1 Course_Materials_Part1/Course_Materials_Part1/Video_Lecture_NBs")

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# survived    891 non-null int64
# pclass      891 non-null int64
# sex         891 non-null object
# age         714 non-null float64
# sibsp       891 non-null int64
# parch       891 non-null int64
# fare        891 non-null float64
# embarked    889 non-null object
# deck        203 non-null object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
import matplotlib.pyplot as plt

# %%
titanic.plot(subplots=True,figsize = (12,8),sharex=False)
plt.show()

# %%
## Age Visualization
titanic.age.plot(figsize = (12,8))
plt.show()

# %%
xticks = [x for x in range(0,901,50)]
yticks = [y for y in range(0,81,5)]

# %%
## Customizing Plots
titanic.age.plot(figsize = (12,8),fontsize=13,c="red",linestyle="-",xlim = (0,900),ylim=(0,80),xticks=xticks,yticks=yticks,rot=45)
plt.title(" Titanic - Ages",fontsize=15)
plt.legend(loc="best",fontsize=15)
plt.xlabel("Passenger No.",fontsize=13)
plt.ylabel("Age",fontsize=13)
plt.grid()
plt.show()

# %%
plt.style.available
# Out:
# ['seaborn-muted',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'Solarize_Light2',
#  'fast',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn',
#  'ggplot',
#  'dark_background',
#  'seaborn-notebook',
#  'seaborn-paper',
#  '_classic_test',
#  'tableau-colorblind10',
#  'seaborn-white',
#  'seaborn-bright',
#  'seaborn-deep',
#  'seaborn-darkgrid',
#  'bmh',
#  'classic',
#  'grayscale',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-colorblind',
#  'seaborn-whitegrid',
#  'fivethirtyeight']

# %%
plt.style.use("seaborn")

# %%
## Customizing Plots
titanic.age.plot(figsize = (12,8),fontsize=13,c="red",linestyle="-",xlim = (0,900),ylim=(0,80),xticks=xticks,yticks=yticks,rot=45)
plt.title(" Titanic - Ages",fontsize=15)
plt.legend(loc="best",fontsize=15)
plt.xlabel("Passenger No.",fontsize=13)
plt.ylabel("Age",fontsize=13)
#plt.grid()
plt.show()

# %%
## Histograms

# %%
titanic.age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: age, Length: 88, dtype: int64

# %%
titanic.age.value_counts(bins=10)
# Out:
# (16.336, 24.294]    177
# (24.294, 32.252]    169
# (32.252, 40.21]     118
# (40.21, 48.168]      70
# (0.339, 8.378]       54
# (8.378, 16.336]      46
# (48.168, 56.126]     45
# (56.126, 64.084]     24
# (64.084, 72.042]      9
# (72.042, 80.0]        2
# Name: age, dtype: int64

# %%
titanic.age.plot(kind="hist",figsize=(12,8),fontsize=15,bins=80)
plt.show()

# %%
titanic.age.hist(figsize=(12,8),bins=80,xlabelsize=15,ylabelsize=15)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.hist(titanic.age,bins=80,density=False,cumulative=False)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.hist(titanic.age,bins=80,density=True,cumulative=False)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.hist(titanic.age,bins=80,density=True,cumulative=True)
plt.show()

# %%
## Barcharts and Piecharts

# %%
summer_2012 = pd.read_csv("summer_2012.csv",index_col="Country")

# %%
summer_2012.head()
# Out:
#          Medal
# Country
# USA        250
# RUS        130
# CHN        128
# GBR        126
# AUS        114

# %%
summer_2012.Medal.plot(kind="bar",figsize=(12,8),fontsize=12)
plt.show()

# %%
summer_2012.Medal.sort_values(ascending=True).plot(kind="barh",figsize=(12,8),fontsize=12)
plt.show()

# %%
summer_2012.Medal.plot(kind="pie",figsize=(12,8),fontsize=12)
plt.show()

# %%
## Scatterplots

# %%
titanic.plot(kind="scatter",x="age",y="fare",figsize=(12,8),c="pclass",colormap="viridis",marker="x",s=20)
plt.show()
